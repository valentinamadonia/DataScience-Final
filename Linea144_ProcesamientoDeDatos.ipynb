# %% [markdown]
# # ***Línea 144 - Grupo 2***
#
#
# ---
# La Línea 144 brinda atención telefónica especializada a mujeres víctimas de violencia de género durante las 24 horas, los 365 días del año.
# Ofrece información, contención y asesoramiento en aquellas temáticas relacionadas con la violencia física, psicológica, sexual, económica y patrimonial, y simbólica. Su objetivo es acompañar en las distintas situaciones, ya sea antes, durante o después de un episodio de violencia.
# El dataset recopila la información recuperada de la página https://datos.gob.ar/ consolidando desde el 2020 hasta el 2023.
#
# Dataset: https://www.kaggle.com/datasets/aracelifernandez/base-de-datos-linea-144-argentina<br>
# Información de columnas: https://www.datos.gob.ar/dataset/generos-base-datos-linea-144/archivo/generos_1.4

# %% [markdown]
# El objetivo es analizar cómo han variado los casos de violencia a lo largo del tiempo, prestando especial atención a los períodos  durante y después de las restricciones de la pandemia. Determinar cuáles tipos de violencia (física, psicológica, sexual, económica, etc.) han mostrado mayores variaciones y en qué contexto (doméstica, institucional, laboral, etc.). Investigar cómo factores como la edad influyen en los tipos de violencia reportados. La idea es desarrollar modelos predictivos para anticipar posibles tendencias en la incidencia de violencia en los próximos años.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import sklearn
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Science/Linea 144.csv', delimiter = ',')
df_final = df.copy()

# %%
df_final['prov_persona_en_situacion_violencia'].describe()
# Out:
# count            89540
# unique              27
# top       Buenos Aires
# freq             48565
# Name: prov_persona_en_situacion_violencia, dtype: object

# %%
pd.options.display.max_columns = None # Muestra todas las columnas al imprimir df

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                        Buenos Aires
# 3      2023    1/1/2023                          Entre Ríos
# 4      2023    1/1/2023                             Mendoza
# ...     ...         ...                                 ...
# 89535  2020  12/31/2020                        Buenos Aires
# 89536  2020  12/31/2020                        Buenos Aires
# 89537  2020  12/31/2020                        Buenos Aires
# 89538  2020  12/31/2020                        Buenos Aires
# 89539  2020  12/31/2020                        Buenos Aires
#
#       genero_persona_en_situacion_de_violencia  \
# 0                                        Mujer
# 1                                        Mujer
# 2                                        Mujer
# 3                                        Mujer
# 4                                        Mujer
# ...                                        ...
# 89535                                    Mujer
# 89536                                    Mujer
# 89537                                    Mujer
# 89538                                    Mujer
# 89539                                    Mujer
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                         NaN
# 1                                        19.0
# 2                                        46.0
# 3                                        28.0
# 4                                        34.0
# ...                                       ...
# 89535                                    30.0
# 89536                                    40.0
# 89537                                    22.0
# 89538                                    44.0
# 89539                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                                   NaN
# 1                                             Argentina
# 2                                             Argentina
# 3                                                   NaN
# 4                                             Argentina
# ...                                                 ...
# 89535                                               NaN
# 89536                                               NaN
# 89537                                               NaN
# 89538                                         Argentina
# 89539                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           Si                            Si
# 3                           No                            Si
# 4                           No                            Si
# ...                        ...                           ...
# 89535                       Si                            Si
# 89536                       Si                            Si
# 89537                       Si                            Si
# 89538                       Si                            Si
# 89539                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           No                                        No
# 1                           Si                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        No
# ...                        ...                                       ...
# 89535                       No                                        No
# 89536                       No                                        No
# 89537                       No                                        No
# 89538                       No                                        No
# 89539                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          Si
# 1                              No                          No
# 2                              Si                          Si
# 3                              Si                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 89535                          Si                          Si
# 89536                          Si                          Si
# 89537                          Si                          Si
# 89538                          Si                          Si
# 89539                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 89535                                   No                             No
# 89536                                   No                             No
# 89537                                   No                             No
# 89538                                   No                             No
# 89539                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 89535                                               No
# 89536                                               No
# 89537                                               No
# 89538                                               No
# 89539                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 89535                                No                               No
# 89536                                No                               No
# 89537                                No                               No
# 89538                                No                               No
# 89539                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                          Pareja
# 1                               No                            Otro
# 2                               No                          Pareja
# 3                               No                          Pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 89535                           No                          Pareja
# 89536                           No                   Otro familiar
# 89537                           No                       Ex pareja
# 89538                           No                       Ex pareja
# 89539                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon            17569053
# 3                             Varon             1426426
# 4                             Varon             2014533
# ...                             ...                 ...
# 89535                         Varon            17569053
# 89536                          Otro            17569053
# 89537                         Varon            17569053
# 89538                         Varon            17569053
# 89539                         Varon            17569053
#
# [89540 rows x 21 columns]

# %% [markdown]
# # **Descripción de la base y sus variables**

# %%
df_final.columns
# Out:
# Index(['Anio', 'Fecha', 'prov_persona_en_situacion_violencia',
#        'genero_persona_en_situacion_de_violencia',
#        'edad_persona_en_situacion_de_violencia',
#        'pais_nacimiento_persona_en_situacion_de_violencia',
#        'tipo_de_violencia_fisica', 'tipo_de_violencia_psicologica',
#        'tipo_de_violencia_sexual', 'tipo_de_violencia_economica_y_patrimonial',
#        'tipo_de_violencia_simbolica', 'tipo_de_violencia_domestica',
#        'modalidad_de_violencia_institucional',
#        'modalidad_de_violencia_laboral',
#        'modalidad_violencia_contra_libertad_reproductiva',
#        'modalidad_de_violencia_obstetrica', 'modalidad_de_violencia_mediatica',
#        'modalidad_de_violencia_otras', 'vinculo_con_la_persona_agresora',
#        'genero_de_la_persona_agresora', 'poblacion_provincia'],
#       dtype='object')

# %%
# Gráfico de valores faltantes
sns.heatmap(df_final.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# La mayoría de las columnas del dataset estan completas, salvo las columnas de género, edad y país de nacimiento de la persona en situación de violencia, como también vínculo y género de la persona agresora.

# %%
df_info_nulos = pd.DataFrame()
df_info_nulos['Cantidad'] = df_final.isna().sum()
df_info_nulos['Porcentaje'] = (df_final.isnull().mean() * 100).round(2)
df_info_nulos['Tipo de dato'] = df_final.dtypes
df_info_nulos.sort_values(by='Porcentaje', ascending=False)
# Out:
#                                                    Cantidad  Porcentaje  \
# pais_nacimiento_persona_en_situacion_de_violencia     30281       33.82
# edad_persona_en_situacion_de_violencia                17278       19.30
# genero_de_la_persona_agresora                          9213       10.29
# vinculo_con_la_persona_agresora                        3395        3.79
# genero_persona_en_situacion_de_violencia               1904        2.13
# poblacion_provincia                                    1312        1.47
# modalidad_de_violencia_institucional                      0        0.00
# modalidad_de_violencia_otras                              0        0.00
# modalidad_de_violencia_mediatica                          0        0.00
# modalidad_de_violencia_obstetrica                         0        0.00
# modalidad_violencia_contra_libertad_reproductiva          0        0.00
# modalidad_de_violencia_laboral                            0        0.00
# Anio                                                      0        0.00
# tipo_de_violencia_domestica                               0        0.00
# Fecha                                                     0        0.00
# tipo_de_violencia_economica_y_patrimonial                 0        0.00
# tipo_de_violencia_sexual                                  0        0.00
# tipo_de_violencia_psicologica                             0        0.00
# tipo_de_violencia_fisica                                  0        0.00
# prov_persona_en_situacion_violencia                       0        0.00
# tipo_de_violencia_simbolica                               0        0.00
#
#                                                   Tipo de dato
# pais_nacimiento_persona_en_situacion_de_violencia       object
# edad_persona_en_situacion_de_violencia                 float64
# genero_de_la_persona_agresora                           object
# vinculo_con_la_persona_agresora                         object
# genero_persona_en_situacion_de_violencia                object
# poblacion_provincia                                     object
# modalidad_de_violencia_institucional                    object
# modalidad_de_violencia_otras                            object
# modalidad_de_violencia_mediatica                        object
# modalidad_de_violencia_obstetrica                       object
# modalidad_violencia_contra_libertad_reproductiva        object
# modalidad_de_violencia_laboral                          object
# Anio                                                     int64
# tipo_de_violencia_domestica                             object
# Fecha                                                   object
# tipo_de_violencia_economica_y_patrimonial               object
# tipo_de_violencia_sexual                                object
# tipo_de_violencia_psicologica                           object
# tipo_de_violencia_fisica                                object
# prov_persona_en_situacion_violencia                     object
# tipo_de_violencia_simbolica                             object

# %% [markdown]
# ## **Provincia**
# Provincia en donde la persona en situación de violencia declara estar residiendo al momento de la consulta

# %%
df_final['prov_persona_en_situacion_violencia'].unique()
# Out:
# array(['Buenos Aires', 'Entre Ríos', 'Mendoza', 'Tucumán', 'Santa Fe',
#        'Misiones', 'San Luis', 'Córdoba', 'Jujuy', 'Río Negro',
#        'San Juan', 'Salta', 'Santiago Del Estero',
#        'Ciudad Autónoma de Buenos Aires', 'Chaco', 'Formosa', 'Sin datos',
#        'Neuquén', 'Catamarca', 'Corrientes', 'La Rioja', 'La Pampa',
#        'Chubut', 'Sin Datos', 'Santa Cruz',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur',
#        'Santiago del Estero'], dtype=object)

# %% [markdown]
# En esta variable se puede detectar los valores "Sin Datos" y "Sin datos" que se reemplazarán por nan. Además la provincia Santiago del Estero se encuentra escrita de dos maneras diferentes (Santiago Del Estero y Santiago del Estero), se reemplazará la primera opción por la segunda.

# %%
df_final['prov_persona_en_situacion_violencia'] = df_final['prov_persona_en_situacion_violencia'].replace('Sin Datos', np.nan)
df_final['prov_persona_en_situacion_violencia'] = df_final['prov_persona_en_situacion_violencia'].replace('Sin datos', np.nan)
df_final['prov_persona_en_situacion_violencia'] = df_final['prov_persona_en_situacion_violencia'].replace('Santiago Del Estero', 'Santiago del Estero')

# %%
 sns.countplot(x='prov_persona_en_situacion_violencia', data=df_final, order=df_final['prov_persona_en_situacion_violencia'].value_counts().index)
 plt.xticks(rotation=90)
 plt.show()

# %%
# Cantidad de valores faltantes
df_final['prov_persona_en_situacion_violencia'].isna().sum()
# Out:
# 1312

# %%
#Porcentaje de valores faltantes
df_final['prov_persona_en_situacion_violencia'].isna().sum()/ len(df_final) * 100
# Out:
# 1.4652669198123742

# %% [markdown]
# Los datos nulos se reemplazarán por la provincia más frecuente, en este caso Buenos Aires

# %%
imputer_most_frequent = SimpleImputer(missing_values=np.nan, strategy="most_frequent")

# %%
df_final["prov_persona_en_situacion_violencia"].mode()
# Out:
# 0    Buenos Aires
# Name: prov_persona_en_situacion_violencia, dtype: object

# %%
# Se reemplaza los nan por el valor mas frecuente
prov_imputado = imputer_most_frequent.fit_transform(df_final[['prov_persona_en_situacion_violencia']])

# %%
prov_imputado = prov_imputado.squeeze(axis=1)

# %%
df_final["prov_persona_en_situacion_violencia"] = prov_imputado

# %%
df_final['prov_persona_en_situacion_violencia'].isna().sum()
# Out:
# 0

# %%
df_final.shape
# Out:
# (89540, 21)

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                        Buenos Aires
# 3      2023    1/1/2023                          Entre Ríos
# 4      2023    1/1/2023                             Mendoza
# ...     ...         ...                                 ...
# 89535  2020  12/31/2020                        Buenos Aires
# 89536  2020  12/31/2020                        Buenos Aires
# 89537  2020  12/31/2020                        Buenos Aires
# 89538  2020  12/31/2020                        Buenos Aires
# 89539  2020  12/31/2020                        Buenos Aires
#
#       genero_persona_en_situacion_de_violencia  \
# 0                                        Mujer
# 1                                        Mujer
# 2                                        Mujer
# 3                                        Mujer
# 4                                        Mujer
# ...                                        ...
# 89535                                    Mujer
# 89536                                    Mujer
# 89537                                    Mujer
# 89538                                    Mujer
# 89539                                    Mujer
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                         NaN
# 1                                        19.0
# 2                                        46.0
# 3                                        28.0
# 4                                        34.0
# ...                                       ...
# 89535                                    30.0
# 89536                                    40.0
# 89537                                    22.0
# 89538                                    44.0
# 89539                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                                   NaN
# 1                                             Argentina
# 2                                             Argentina
# 3                                                   NaN
# 4                                             Argentina
# ...                                                 ...
# 89535                                               NaN
# 89536                                               NaN
# 89537                                               NaN
# 89538                                         Argentina
# 89539                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           Si                            Si
# 3                           No                            Si
# 4                           No                            Si
# ...                        ...                           ...
# 89535                       Si                            Si
# 89536                       Si                            Si
# 89537                       Si                            Si
# 89538                       Si                            Si
# 89539                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           No                                        No
# 1                           Si                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        No
# ...                        ...                                       ...
# 89535                       No                                        No
# 89536                       No                                        No
# 89537                       No                                        No
# 89538                       No                                        No
# 89539                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          Si
# 1                              No                          No
# 2                              Si                          Si
# 3                              Si                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 89535                          Si                          Si
# 89536                          Si                          Si
# 89537                          Si                          Si
# 89538                          Si                          Si
# 89539                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 89535                                   No                             No
# 89536                                   No                             No
# 89537                                   No                             No
# 89538                                   No                             No
# 89539                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 89535                                               No
# 89536                                               No
# 89537                                               No
# 89538                                               No
# 89539                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 89535                                No                               No
# 89536                                No                               No
# 89537                                No                               No
# 89538                                No                               No
# 89539                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                          Pareja
# 1                               No                            Otro
# 2                               No                          Pareja
# 3                               No                          Pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 89535                           No                          Pareja
# 89536                           No                   Otro familiar
# 89537                           No                       Ex pareja
# 89538                           No                       Ex pareja
# 89539                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon            17569053
# 3                             Varon             1426426
# 4                             Varon             2014533
# ...                             ...                 ...
# 89535                         Varon            17569053
# 89536                          Otro            17569053
# 89537                         Varon            17569053
# 89538                         Varon            17569053
# 89539                         Varon            17569053
#
# [89540 rows x 21 columns]

# %% [markdown]
# ## **Género**
# Identidad de género autopercibida de la persona en situación de violencia

# %%
df_final['genero_persona_en_situacion_de_violencia'].describe()
# Out:
# count     87636
# unique       12
# top       Mujer
# freq      86883
# Name: genero_persona_en_situacion_de_violencia, dtype: object

# %%
df_final['genero_persona_en_situacion_de_violencia'].value_counts() / len(df_final) * 100
# Out:
# genero_persona_en_situacion_de_violencia
# Mujer          97.032611
# Varon           0.389770
# Transgenero     0.168640
# Mujer Trans     0.157472
# Otro            0.074827
# Varón Trans     0.014519
# Varon Trans     0.013402
# Travesti        0.012285
# Intersexual     0.004467
# No Binarie      0.003350
# Varon trans     0.001117
# Queer           0.001117
# Name: count, dtype: float64

# %% [markdown]
# Como el 97% de los datos ingresados corresponden al género Mujer, solo se tendran en cuenta estos casos.

# %%
# Obtengo solo los datos de género Mujer
df_final = df_final[df_final['genero_persona_en_situacion_de_violencia'] == 'Mujer']
# Comprobación
df_final['genero_persona_en_situacion_de_violencia'].unique()
# Out:
# array(['Mujer'], dtype=object)

# %%
# Elimino la columna género
df_final = df_final.drop(columns=['genero_persona_en_situacion_de_violencia'])

# %%
df_final.shape
# Out:
# (86883, 20)

# %% [markdown]
# Se eliminaron 753 datos

# %% [markdown]
# ## **Edad**
# Edad declarada de la persona en situación de violencia al momento en que se ingresó la consulta

# %%
df_final['edad_persona_en_situacion_de_violencia'].describe()
# Out:
# count    70789.000000
# mean        35.685657
# std         12.567342
# min          1.000000
# 25%         27.000000
# 50%         34.000000
# 75%         42.000000
# max        103.000000
# Name: edad_persona_en_situacion_de_violencia, dtype: float64

# %%
df_final['edad_persona_en_situacion_de_violencia'].unique()
# Out:
# array([ nan,  19.,  46.,  28.,  34.,  38.,  57.,  39.,  24.,  22.,  52.,
#         65.,  26.,  41.,  44.,  40.,  27.,  42.,  25.,  49.,  15.,  23.,
#         20.,   5.,  29.,  45.,  18.,  33.,  36.,  31.,  37.,  51.,  30.,
#         17.,  35.,  48.,  32.,  43.,  55.,  59.,  50.,  21.,  53.,  54.,
#         72.,  56.,  12.,  60.,  47.,  62.,  64.,  16.,  70.,  71.,  61.,
#         68.,   7.,  66.,  67.,  58.,  74.,  79.,  73.,  13.,  10.,  76.,
#         75.,  14.,   4.,  63.,  11.,  77.,  87.,  69.,  86.,   9.,   8.,
#         88.,  80.,  78.,  85.,  84.,  82.,  92.,   2.,   6.,  81.,  90.,
#          1.,  94.,  83.,  89.,   3., 103.,  93.,  91.,  95., 100.,  97.])

# %% [markdown]
# Vemos que el mínimo es 1 y el máximo es 103 por lo cual deberíamos ver posibles outliers para la variable. Agregamos la distribución de la variable edad

# %%
df_final['edad_persona_en_situacion_de_violencia'].hist(bins=100, color='pink')
plt.title('Distribución de edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Boxplot edad para la comprobacion de outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x='edad_persona_en_situacion_de_violencia',data=df_final)
plt.title('Boxplot de la edad')
plt.xlabel('Edad')
plt.show()

# %%
# Rango Intercuartílico (OUTLIERS)
# Elimina todos aquellos valores menores al primer cuartil menos 1.5 veces el RIC o mayores al tercer cuartil más 1.5 veces el RIC.
q1 = df_final['edad_persona_en_situacion_de_violencia'].quantile(0.25)
q3 = df_final['edad_persona_en_situacion_de_violencia'].quantile(0.75)
iqr = q3 - q1
lb = q1 - (iqr * 1.5)
ub = q3 + (iqr * 1.5)
df_final = df_final[(df_final['edad_persona_en_situacion_de_violencia'] > lb) & (df_final['edad_persona_en_situacion_de_violencia'] < ub)]
df_final.reset_index(drop=True, inplace=True)
print(lb, ub)
# Out:
# 4.5 64.5

# %%
df_final.shape
# Out:
# (68431, 20)

# %%
df_final['edad_persona_en_situacion_de_violencia'].hist(bins=100, color='pink')
plt.title('Distribución de edades')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                          Entre Ríos
# 3      2023    1/1/2023                             Mendoza
# 4      2023    1/1/2023                        Buenos Aires
# ...     ...         ...                                 ...
# 68426  2020  12/31/2020                        Buenos Aires
# 68427  2020  12/31/2020                        Buenos Aires
# 68428  2020  12/31/2020                        Buenos Aires
# 68429  2020  12/31/2020                        Buenos Aires
# 68430  2020  12/31/2020                        Buenos Aires
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                        19.0
# 1                                        46.0
# 2                                        28.0
# 3                                        34.0
# 4                                        38.0
# ...                                       ...
# 68426                                    30.0
# 68427                                    40.0
# 68428                                    22.0
# 68429                                    44.0
# 68430                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                             Argentina
# 1                                             Argentina
# 2                                                   NaN
# 3                                             Argentina
# 4                                             Paraguaya
# ...                                                 ...
# 68426                                               NaN
# 68427                                               NaN
# 68428                                               NaN
# 68429                                         Argentina
# 68430                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           No                            Si
# 3                           No                            Si
# 4                           Si                            Si
# ...                        ...                           ...
# 68426                       Si                            Si
# 68427                       Si                            Si
# 68428                       Si                            Si
# 68429                       Si                            Si
# 68430                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           Si                                        No
# 1                           No                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        Si
# ...                        ...                                       ...
# 68426                       No                                        No
# 68427                       No                                        No
# 68428                       No                                        No
# 68429                       No                                        No
# 68430                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          No
# 1                              Si                          Si
# 2                              Si                          Si
# 3                              No                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 68426                          Si                          Si
# 68427                          Si                          Si
# 68428                          Si                          Si
# 68429                          Si                          Si
# 68430                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 68426                                   No                             No
# 68427                                   No                             No
# 68428                                   No                             No
# 68429                                   No                             No
# 68430                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 68426                                               No
# 68427                                               No
# 68428                                               No
# 68429                                               No
# 68430                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 68426                                No                               No
# 68427                                No                               No
# 68428                                No                               No
# 68429                                No                               No
# 68430                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                            Otro
# 1                               No                          Pareja
# 2                               No                          Pareja
# 3                               No                       Ex pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 68426                           No                          Pareja
# 68427                           No                   Otro familiar
# 68428                           No                       Ex pareja
# 68429                           No                       Ex pareja
# 68430                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon             1426426
# 3                             Varon             2014533
# 4                             Varon            17569053
# ...                             ...                 ...
# 68426                         Varon            17569053
# 68427                          Otro            17569053
# 68428                         Varon            17569053
# 68429                         Varon            17569053
# 68430                         Varon            17569053
#
# [68431 rows x 20 columns]

# %%
# Boxplot edad para la comprobacion de outliers
plt.figure(figsize=(10, 6))
sns.boxplot(x='edad_persona_en_situacion_de_violencia',data=df_final)
plt.title('Boxplot de la edad')
plt.xlabel('Edad')
plt.show()

# %%
df_final['edad_persona_en_situacion_de_violencia'].unique()
# Out:
# array([19., 46., 28., 34., 38., 57., 39., 24., 22., 52., 26., 41., 44.,
#        40., 27., 42., 25., 49., 15., 23., 20.,  5., 29., 45., 18., 33.,
#        36., 31., 37., 51., 30., 17., 35., 48., 32., 43., 55., 59., 50.,
#        21., 53., 54., 56., 12., 60., 47., 62., 64., 16., 61.,  7., 58.,
#        13., 10., 14., 63., 11.,  9.,  8.,  6.])

# %%
df_final['edad_persona_en_situacion_de_violencia'].describe()
# Out:
# count    68431.00000
# mean        34.45288
# std         10.65308
# min          5.00000
# 25%         26.00000
# 50%         33.00000
# 75%         41.00000
# max         64.00000
# Name: edad_persona_en_situacion_de_violencia, dtype: float64

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                          Entre Ríos
# 3      2023    1/1/2023                             Mendoza
# 4      2023    1/1/2023                        Buenos Aires
# ...     ...         ...                                 ...
# 68426  2020  12/31/2020                        Buenos Aires
# 68427  2020  12/31/2020                        Buenos Aires
# 68428  2020  12/31/2020                        Buenos Aires
# 68429  2020  12/31/2020                        Buenos Aires
# 68430  2020  12/31/2020                        Buenos Aires
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                        19.0
# 1                                        46.0
# 2                                        28.0
# 3                                        34.0
# 4                                        38.0
# ...                                       ...
# 68426                                    30.0
# 68427                                    40.0
# 68428                                    22.0
# 68429                                    44.0
# 68430                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                             Argentina
# 1                                             Argentina
# 2                                                   NaN
# 3                                             Argentina
# 4                                             Paraguaya
# ...                                                 ...
# 68426                                               NaN
# 68427                                               NaN
# 68428                                               NaN
# 68429                                         Argentina
# 68430                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           No                            Si
# 3                           No                            Si
# 4                           Si                            Si
# ...                        ...                           ...
# 68426                       Si                            Si
# 68427                       Si                            Si
# 68428                       Si                            Si
# 68429                       Si                            Si
# 68430                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           Si                                        No
# 1                           No                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        Si
# ...                        ...                                       ...
# 68426                       No                                        No
# 68427                       No                                        No
# 68428                       No                                        No
# 68429                       No                                        No
# 68430                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          No
# 1                              Si                          Si
# 2                              Si                          Si
# 3                              No                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 68426                          Si                          Si
# 68427                          Si                          Si
# 68428                          Si                          Si
# 68429                          Si                          Si
# 68430                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 68426                                   No                             No
# 68427                                   No                             No
# 68428                                   No                             No
# 68429                                   No                             No
# 68430                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 68426                                               No
# 68427                                               No
# 68428                                               No
# 68429                                               No
# 68430                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 68426                                No                               No
# 68427                                No                               No
# 68428                                No                               No
# 68429                                No                               No
# 68430                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                            Otro
# 1                               No                          Pareja
# 2                               No                          Pareja
# 3                               No                       Ex pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 68426                           No                          Pareja
# 68427                           No                   Otro familiar
# 68428                           No                       Ex pareja
# 68429                           No                       Ex pareja
# 68430                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon             1426426
# 3                             Varon             2014533
# 4                             Varon            17569053
# ...                             ...                 ...
# 68426                         Varon            17569053
# 68427                          Otro            17569053
# 68428                         Varon            17569053
# 68429                         Varon            17569053
# 68430                         Varon            17569053
#
# [68431 rows x 20 columns]

# %%
#Cantidad de datos faltantes
df_final['edad_persona_en_situacion_de_violencia'].isna().sum()
# Out:
# 0

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                          Entre Ríos
# 3      2023    1/1/2023                             Mendoza
# 4      2023    1/1/2023                        Buenos Aires
# ...     ...         ...                                 ...
# 68426  2020  12/31/2020                        Buenos Aires
# 68427  2020  12/31/2020                        Buenos Aires
# 68428  2020  12/31/2020                        Buenos Aires
# 68429  2020  12/31/2020                        Buenos Aires
# 68430  2020  12/31/2020                        Buenos Aires
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                        19.0
# 1                                        46.0
# 2                                        28.0
# 3                                        34.0
# 4                                        38.0
# ...                                       ...
# 68426                                    30.0
# 68427                                    40.0
# 68428                                    22.0
# 68429                                    44.0
# 68430                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                             Argentina
# 1                                             Argentina
# 2                                                   NaN
# 3                                             Argentina
# 4                                             Paraguaya
# ...                                                 ...
# 68426                                               NaN
# 68427                                               NaN
# 68428                                               NaN
# 68429                                         Argentina
# 68430                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           No                            Si
# 3                           No                            Si
# 4                           Si                            Si
# ...                        ...                           ...
# 68426                       Si                            Si
# 68427                       Si                            Si
# 68428                       Si                            Si
# 68429                       Si                            Si
# 68430                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           Si                                        No
# 1                           No                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        Si
# ...                        ...                                       ...
# 68426                       No                                        No
# 68427                       No                                        No
# 68428                       No                                        No
# 68429                       No                                        No
# 68430                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          No
# 1                              Si                          Si
# 2                              Si                          Si
# 3                              No                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 68426                          Si                          Si
# 68427                          Si                          Si
# 68428                          Si                          Si
# 68429                          Si                          Si
# 68430                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 68426                                   No                             No
# 68427                                   No                             No
# 68428                                   No                             No
# 68429                                   No                             No
# 68430                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 68426                                               No
# 68427                                               No
# 68428                                               No
# 68429                                               No
# 68430                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 68426                                No                               No
# 68427                                No                               No
# 68428                                No                               No
# 68429                                No                               No
# 68430                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                            Otro
# 1                               No                          Pareja
# 2                               No                          Pareja
# 3                               No                       Ex pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 68426                           No                          Pareja
# 68427                           No                   Otro familiar
# 68428                           No                       Ex pareja
# 68429                           No                       Ex pareja
# 68430                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon             1426426
# 3                             Varon             2014533
# 4                             Varon            17569053
# ...                             ...                 ...
# 68426                         Varon            17569053
# 68427                          Otro            17569053
# 68428                         Varon            17569053
# 68429                         Varon            17569053
# 68430                         Varon            17569053
#
# [68431 rows x 20 columns]

# %% [markdown]
# ## **Tipos de violencia**
# Tipo de violencia, contemplado por la ley 26.485, que motiva la consulta

# %% [markdown]
# ### **Violencia física**

# %%
df_final['tipo_de_violencia_fisica'].unique()
# Out:
# array(['Si', 'No'], dtype=object)

# %%
df_final['tipo_de_violencia_fisica'].value_counts() / len(df_final) * 100
# Out:
# tipo_de_violencia_fisica
# Si    68.023264
# No    31.976736
# Name: count, dtype: float64

# %%
df_final['tipo_de_violencia_fisica'].describe()
# Out:
# count     68431
# unique        2
# top          Si
# freq      46549
# Name: tipo_de_violencia_fisica, dtype: object

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                          Entre Ríos
# 3      2023    1/1/2023                             Mendoza
# 4      2023    1/1/2023                        Buenos Aires
# ...     ...         ...                                 ...
# 68426  2020  12/31/2020                        Buenos Aires
# 68427  2020  12/31/2020                        Buenos Aires
# 68428  2020  12/31/2020                        Buenos Aires
# 68429  2020  12/31/2020                        Buenos Aires
# 68430  2020  12/31/2020                        Buenos Aires
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                        19.0
# 1                                        46.0
# 2                                        28.0
# 3                                        34.0
# 4                                        38.0
# ...                                       ...
# 68426                                    30.0
# 68427                                    40.0
# 68428                                    22.0
# 68429                                    44.0
# 68430                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                             Argentina
# 1                                             Argentina
# 2                                                   NaN
# 3                                             Argentina
# 4                                             Paraguaya
# ...                                                 ...
# 68426                                               NaN
# 68427                                               NaN
# 68428                                               NaN
# 68429                                         Argentina
# 68430                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           No                            Si
# 3                           No                            Si
# 4                           Si                            Si
# ...                        ...                           ...
# 68426                       Si                            Si
# 68427                       Si                            Si
# 68428                       Si                            Si
# 68429                       Si                            Si
# 68430                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           Si                                        No
# 1                           No                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        Si
# ...                        ...                                       ...
# 68426                       No                                        No
# 68427                       No                                        No
# 68428                       No                                        No
# 68429                       No                                        No
# 68430                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          No
# 1                              Si                          Si
# 2                              Si                          Si
# 3                              No                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 68426                          Si                          Si
# 68427                          Si                          Si
# 68428                          Si                          Si
# 68429                          Si                          Si
# 68430                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 68426                                   No                             No
# 68427                                   No                             No
# 68428                                   No                             No
# 68429                                   No                             No
# 68430                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 68426                                               No
# 68427                                               No
# 68428                                               No
# 68429                                               No
# 68430                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 68426                                No                               No
# 68427                                No                               No
# 68428                                No                               No
# 68429                                No                               No
# 68430                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                            Otro
# 1                               No                          Pareja
# 2                               No                          Pareja
# 3                               No                       Ex pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 68426                           No                          Pareja
# 68427                           No                   Otro familiar
# 68428                           No                       Ex pareja
# 68429                           No                       Ex pareja
# 68430                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon             1426426
# 3                             Varon             2014533
# 4                             Varon            17569053
# ...                             ...                 ...
# 68426                         Varon            17569053
# 68427                          Otro            17569053
# 68428                         Varon            17569053
# 68429                         Varon            17569053
# 68430                         Varon            17569053
#
# [68431 rows x 20 columns]

# %% [markdown]
# ### **Violencia psicológica**

# %%
df_final['tipo_de_violencia_psicologica'].unique()
# Out:
# array(['Si', 'No'], dtype=object)

# %%
df_final['tipo_de_violencia_psicologica'].value_counts() / len(df_final) * 100
# Out:
# tipo_de_violencia_psicologica
# Si    95.896597
# No     4.103403
# Name: count, dtype: float64

# %%
df_final['tipo_de_violencia_psicologica'].describe()
# Out:
# count     68431
# unique        2
# top          Si
# freq      65623
# Name: tipo_de_violencia_psicologica, dtype: object

# %% [markdown]
# ### **Violencia sexual**

# %%
df_final['tipo_de_violencia_sexual'].unique()
# Out:
# array(['Si', 'No'], dtype=object)

# %%
# Se reemplaza "SI" por "Si"
df_final['tipo_de_violencia_sexual'].replace("SI","Si", inplace=True)

# %%
df_final['tipo_de_violencia_sexual'].value_counts() / len(df_final) * 100
# Out:
# tipo_de_violencia_sexual
# No    84.889889
# Si    15.110111
# Name: count, dtype: float64

# %%
df_final['tipo_de_violencia_sexual'].describe()
# Out:
# count     68431
# unique        2
# top          No
# freq      58091
# Name: tipo_de_violencia_sexual, dtype: object

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                          Entre Ríos
# 3      2023    1/1/2023                             Mendoza
# 4      2023    1/1/2023                        Buenos Aires
# ...     ...         ...                                 ...
# 68426  2020  12/31/2020                        Buenos Aires
# 68427  2020  12/31/2020                        Buenos Aires
# 68428  2020  12/31/2020                        Buenos Aires
# 68429  2020  12/31/2020                        Buenos Aires
# 68430  2020  12/31/2020                        Buenos Aires
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                        19.0
# 1                                        46.0
# 2                                        28.0
# 3                                        34.0
# 4                                        38.0
# ...                                       ...
# 68426                                    30.0
# 68427                                    40.0
# 68428                                    22.0
# 68429                                    44.0
# 68430                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                             Argentina
# 1                                             Argentina
# 2                                                   NaN
# 3                                             Argentina
# 4                                             Paraguaya
# ...                                                 ...
# 68426                                               NaN
# 68427                                               NaN
# 68428                                               NaN
# 68429                                         Argentina
# 68430                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           No                            Si
# 3                           No                            Si
# 4                           Si                            Si
# ...                        ...                           ...
# 68426                       Si                            Si
# 68427                       Si                            Si
# 68428                       Si                            Si
# 68429                       Si                            Si
# 68430                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           Si                                        No
# 1                           No                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        Si
# ...                        ...                                       ...
# 68426                       No                                        No
# 68427                       No                                        No
# 68428                       No                                        No
# 68429                       No                                        No
# 68430                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          No
# 1                              Si                          Si
# 2                              Si                          Si
# 3                              No                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 68426                          Si                          Si
# 68427                          Si                          Si
# 68428                          Si                          Si
# 68429                          Si                          Si
# 68430                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 68426                                   No                             No
# 68427                                   No                             No
# 68428                                   No                             No
# 68429                                   No                             No
# 68430                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 68426                                               No
# 68427                                               No
# 68428                                               No
# 68429                                               No
# 68430                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 68426                                No                               No
# 68427                                No                               No
# 68428                                No                               No
# 68429                                No                               No
# 68430                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                            Otro
# 1                               No                          Pareja
# 2                               No                          Pareja
# 3                               No                       Ex pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 68426                           No                          Pareja
# 68427                           No                   Otro familiar
# 68428                           No                       Ex pareja
# 68429                           No                       Ex pareja
# 68430                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon             1426426
# 3                             Varon             2014533
# 4                             Varon            17569053
# ...                             ...                 ...
# 68426                         Varon            17569053
# 68427                          Otro            17569053
# 68428                         Varon            17569053
# 68429                         Varon            17569053
# 68430                         Varon            17569053
#
# [68431 rows x 20 columns]

# %% [markdown]
# ### **Violencia económica y patrimonial**

# %%
df_final['tipo_de_violencia_economica_y_patrimonial'].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
df_final['tipo_de_violencia_economica_y_patrimonial'].value_counts() / len(df_final) * 100
# Out:
# tipo_de_violencia_economica_y_patrimonial
# No    57.304438
# Si    42.695562
# Name: count, dtype: float64

# %%
df_final['tipo_de_violencia_economica_y_patrimonial'].describe()
# Out:
# count     68431
# unique        2
# top          No
# freq      39214
# Name: tipo_de_violencia_economica_y_patrimonial, dtype: object

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                          Entre Ríos
# 3      2023    1/1/2023                             Mendoza
# 4      2023    1/1/2023                        Buenos Aires
# ...     ...         ...                                 ...
# 68426  2020  12/31/2020                        Buenos Aires
# 68427  2020  12/31/2020                        Buenos Aires
# 68428  2020  12/31/2020                        Buenos Aires
# 68429  2020  12/31/2020                        Buenos Aires
# 68430  2020  12/31/2020                        Buenos Aires
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                        19.0
# 1                                        46.0
# 2                                        28.0
# 3                                        34.0
# 4                                        38.0
# ...                                       ...
# 68426                                    30.0
# 68427                                    40.0
# 68428                                    22.0
# 68429                                    44.0
# 68430                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                             Argentina
# 1                                             Argentina
# 2                                                   NaN
# 3                                             Argentina
# 4                                             Paraguaya
# ...                                                 ...
# 68426                                               NaN
# 68427                                               NaN
# 68428                                               NaN
# 68429                                         Argentina
# 68430                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           No                            Si
# 3                           No                            Si
# 4                           Si                            Si
# ...                        ...                           ...
# 68426                       Si                            Si
# 68427                       Si                            Si
# 68428                       Si                            Si
# 68429                       Si                            Si
# 68430                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           Si                                        No
# 1                           No                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        Si
# ...                        ...                                       ...
# 68426                       No                                        No
# 68427                       No                                        No
# 68428                       No                                        No
# 68429                       No                                        No
# 68430                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          No
# 1                              Si                          Si
# 2                              Si                          Si
# 3                              No                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 68426                          Si                          Si
# 68427                          Si                          Si
# 68428                          Si                          Si
# 68429                          Si                          Si
# 68430                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 68426                                   No                             No
# 68427                                   No                             No
# 68428                                   No                             No
# 68429                                   No                             No
# 68430                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 68426                                               No
# 68427                                               No
# 68428                                               No
# 68429                                               No
# 68430                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 68426                                No                               No
# 68427                                No                               No
# 68428                                No                               No
# 68429                                No                               No
# 68430                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                            Otro
# 1                               No                          Pareja
# 2                               No                          Pareja
# 3                               No                       Ex pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 68426                           No                          Pareja
# 68427                           No                   Otro familiar
# 68428                           No                       Ex pareja
# 68429                           No                       Ex pareja
# 68430                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon             1426426
# 3                             Varon             2014533
# 4                             Varon            17569053
# ...                             ...                 ...
# 68426                         Varon            17569053
# 68427                          Otro            17569053
# 68428                         Varon            17569053
# 68429                         Varon            17569053
# 68430                         Varon            17569053
#
# [68431 rows x 20 columns]

# %% [markdown]
# ### **Violencia simbólica**

# %%
df_final['tipo_de_violencia_simbolica'].unique()
# Out:
# array(['No', 'Si', 'SI'], dtype=object)

# %%
df_final['tipo_de_violencia_simbolica'].replace("SI","Si",inplace=True)

# %%
df_final['tipo_de_violencia_simbolica'].value_counts() / len(df_final) * 100
# Out:
# tipo_de_violencia_simbolica
# No    64.670982
# Si    35.329018
# Name: count, dtype: float64

# %%
df_final['tipo_de_violencia_simbolica'].describe()
# Out:
# count     68431
# unique        2
# top          No
# freq      44255
# Name: tipo_de_violencia_simbolica, dtype: object

# %% [markdown]
# ### **Violencia doméstica**

# %%
df_final['tipo_de_violencia_domestica'].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
df_final['tipo_de_violencia_domestica'].value_counts() / len(df_final) * 100
# Out:
# tipo_de_violencia_domestica
# Si    92.121991
# No     7.878009
# Name: count, dtype: float64

# %%
df_final['tipo_de_violencia_domestica'].describe()
# Out:
# count     68431
# unique        2
# top          Si
# freq      63040
# Name: tipo_de_violencia_domestica, dtype: object

# %%
df_final
# Out:
#        Anio       Fecha prov_persona_en_situacion_violencia  \
# 0      2023    1/1/2023                        Buenos Aires
# 1      2023    1/1/2023                        Buenos Aires
# 2      2023    1/1/2023                          Entre Ríos
# 3      2023    1/1/2023                             Mendoza
# 4      2023    1/1/2023                        Buenos Aires
# ...     ...         ...                                 ...
# 68426  2020  12/31/2020                        Buenos Aires
# 68427  2020  12/31/2020                        Buenos Aires
# 68428  2020  12/31/2020                        Buenos Aires
# 68429  2020  12/31/2020                        Buenos Aires
# 68430  2020  12/31/2020                        Buenos Aires
#
#        edad_persona_en_situacion_de_violencia  \
# 0                                        19.0
# 1                                        46.0
# 2                                        28.0
# 3                                        34.0
# 4                                        38.0
# ...                                       ...
# 68426                                    30.0
# 68427                                    40.0
# 68428                                    22.0
# 68429                                    44.0
# 68430                                    21.0
#
#       pais_nacimiento_persona_en_situacion_de_violencia  \
# 0                                             Argentina
# 1                                             Argentina
# 2                                                   NaN
# 3                                             Argentina
# 4                                             Paraguaya
# ...                                                 ...
# 68426                                               NaN
# 68427                                               NaN
# 68428                                               NaN
# 68429                                         Argentina
# 68430                                               NaN
#
#       tipo_de_violencia_fisica tipo_de_violencia_psicologica  \
# 0                           Si                            Si
# 1                           Si                            Si
# 2                           No                            Si
# 3                           No                            Si
# 4                           Si                            Si
# ...                        ...                           ...
# 68426                       Si                            Si
# 68427                       Si                            Si
# 68428                       Si                            Si
# 68429                       Si                            Si
# 68430                       Si                            Si
#
#       tipo_de_violencia_sexual tipo_de_violencia_economica_y_patrimonial  \
# 0                           Si                                        No
# 1                           No                                        No
# 2                           No                                        No
# 3                           No                                        No
# 4                           No                                        Si
# ...                        ...                                       ...
# 68426                       No                                        No
# 68427                       No                                        No
# 68428                       No                                        No
# 68429                       No                                        No
# 68430                       No                                        No
#
#       tipo_de_violencia_simbolica tipo_de_violencia_domestica  \
# 0                              No                          No
# 1                              Si                          Si
# 2                              Si                          Si
# 3                              No                          Si
# 4                              No                          Si
# ...                           ...                         ...
# 68426                          Si                          Si
# 68427                          Si                          Si
# 68428                          Si                          Si
# 68429                          Si                          Si
# 68430                          Si                          Si
#
#       modalidad_de_violencia_institucional modalidad_de_violencia_laboral  \
# 0                                       No                             No
# 1                                       No                             No
# 2                                       No                             No
# 3                                       No                             No
# 4                                       No                             No
# ...                                    ...                            ...
# 68426                                   No                             No
# 68427                                   No                             No
# 68428                                   No                             No
# 68429                                   No                             No
# 68430                                   No                             No
#
#       modalidad_violencia_contra_libertad_reproductiva  \
# 0                                                   No
# 1                                                   No
# 2                                                   No
# 3                                                   No
# 4                                                   No
# ...                                                ...
# 68426                                               No
# 68427                                               No
# 68428                                               No
# 68429                                               No
# 68430                                               No
#
#       modalidad_de_violencia_obstetrica modalidad_de_violencia_mediatica  \
# 0                                    No                               No
# 1                                    No                               No
# 2                                    No                               No
# 3                                    No                               No
# 4                                    No                               No
# ...                                 ...                              ...
# 68426                                No                               No
# 68427                                No                               No
# 68428                                No                               No
# 68429                                No                               No
# 68430                                No                               No
#
#       modalidad_de_violencia_otras vinculo_con_la_persona_agresora  \
# 0                               No                            Otro
# 1                               No                          Pareja
# 2                               No                          Pareja
# 3                               No                       Ex pareja
# 4                               No                       Ex pareja
# ...                            ...                             ...
# 68426                           No                          Pareja
# 68427                           No                   Otro familiar
# 68428                           No                       Ex pareja
# 68429                           No                       Ex pareja
# 68430                           No                          Pareja
#
#       genero_de_la_persona_agresora poblacion_provincia
# 0                             Varon            17569053
# 1                             Varon            17569053
# 2                             Varon             1426426
# 3                             Varon             2014533
# 4                             Varon            17569053
# ...                             ...                 ...
# 68426                         Varon            17569053
# 68427                          Otro            17569053
# 68428                         Varon            17569053
# 68429                         Varon            17569053
# 68430                         Varon            17569053
#
# [68431 rows x 20 columns]

# %% [markdown]
# ## **Vínculo con la persona agresora**
# Vínculo que tiene o tenía la persona en situación de violencia con quien ejerce la agresión en el momento en que sucedieron las situaciones de violencia declaradas

# %%
df_final['vinculo_con_la_persona_agresora'].unique()
# Out:
# array(['Otro', 'Pareja', 'Ex pareja', 'Padre o tutor',
#        'Superior jerarquico', nan, 'Otro familiar', 'Madre o tutor'],
#       dtype=object)

# %%
df_final['vinculo_con_la_persona_agresora'].value_counts() / len(df_final) * 100
# Out:
# vinculo_con_la_persona_agresora
# Ex pareja              49.708465
# Pareja                 36.638366
# Otro                    6.877000
# Otro familiar           2.815975
# Padre o tutor           1.335652
# Superior jerarquico     0.455934
# Madre o tutor           0.191434
# Name: count, dtype: float64

# %%
df_final['vinculo_con_la_persona_agresora'].describe()
# Out:
# count         67078
# unique            7
# top       Ex pareja
# freq          34016
# Name: vinculo_con_la_persona_agresora, dtype: object

# %%
# Cantidad de valores faltantes
df_final['vinculo_con_la_persona_agresora'].isna().sum()
# Out:
# 1353

# %%
# Se reemplaza por el mas frecuente
vinculo_imputado = imputer_most_frequent.fit_transform(df_final[['vinculo_con_la_persona_agresora']])

# %%
df_final["vinculo_con_la_persona_agresora"].mode()
# Out:
# 0    Ex pareja
# Name: vinculo_con_la_persona_agresora, dtype: object

# %%
vinculo_imputado = vinculo_imputado.squeeze(axis=1)

# %%
df_final["vinculo_con_la_persona_agresora"] = vinculo_imputado

# %%
df_final['vinculo_con_la_persona_agresora'].isna().sum()
# Out:
# 0

# %%
df_final.shape
# Out:
# (68431, 20)

# %% [markdown]
# ## **Género de la persona agresora**
# Identidad de género de la persona agresora

# %%
df_final["genero_de_la_persona_agresora"].unique()
# Out:
# array(['Varon', nan, 'Mujer', 'Otro', 'No Binarie', 'Transgenero',
#        'Varon Trans', 'Travesti', 'Varon trans', 'Mujer Trans', 'Queer'],
#       dtype=object)

# %%
df_final['genero_de_la_persona_agresora'].value_counts() / len(df_final) * 100
# Out:
# genero_de_la_persona_agresora
# Varon          92.275431
# Mujer           1.008315
# Otro            0.184127
# Varon Trans     0.016075
# Transgenero     0.010229
# Travesti        0.002923
# Varon trans     0.002923
# Mujer Trans     0.002923
# No Binarie      0.001461
# Queer           0.001461
# Name: count, dtype: float64

# %% [markdown]
# El 92% de los agresores son Varon, al ser un porcentaje muy alto, solo nos quedaremos con estos datos.

# %%
df_final = df_final[df_final['genero_de_la_persona_agresora'] == 'Varon']
df_final['genero_de_la_persona_agresora'].unique()
# Out:
# array(['Varon'], dtype=object)

# %% [markdown]
# # **Gráficos**

# %%
# Límites de los bins
bin = [5, 10, 18, 30, 60, 80]
# [5, 10], [10, 18], [18, 30], [30, 60], [60, 80]

labels = ["Infancia", "Adolescencia","Juventud", "Adultez", "Vejez"]

categorias_edades = pd.cut(df["edad_persona_en_situacion_de_violencia"], bins=bin, labels=labels)

# dataframe temporal
categorias_df = pd.DataFrame(categorias_edades, columns=['categorias_edades'])

# Gráfico
plt.figure(figsize=(10, 6))
sns.countplot(x=categorias_edades,palette="Set2")
plt.title('Rango de edades')
plt.ylabel('Recuento')
plt.xlabel('Categoría de edades')

counts = categorias_edades.value_counts().sort_index()
for i, v in enumerate(counts.values):
    plt.annotate(str(v), xy=(i, v), ha='center', va='bottom', fontsize=10)

plt.show()
# Out:
# <ipython-input-82-554e705bae83>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=categorias_edades,palette="Set2")

# %% [markdown]
# Se puede observar que la mayoria de los casos de violencia son en la adultez en el rango de 30 a 60 años

# %%
# Heatmap de tipos de violencia
df_tipos_violencia = df[['tipo_de_violencia_fisica', 'tipo_de_violencia_psicologica', 'tipo_de_violencia_sexual', 'tipo_de_violencia_economica_y_patrimonial', 'tipo_de_violencia_simbolica', 'tipo_de_violencia_domestica']]
# Contar las frecuencias de 'Si' y 'No' para cada tipo de violencia
counts = df_tipos_violencia.apply(pd.Series.value_counts).T
counts = counts[['Si', 'No']].fillna(0)

# Gráfico
plt.figure(figsize=(8, 6))
# fmt g enteros sin formato específico de decimales
sns.heatmap(counts, annot=True, cmap="YlGnBu", fmt='g')
plt.title('Frecuencia de tipos de violencia')
plt.xlabel('Respuesta')
plt.ylabel('Tipo de violencia')
plt.show()

# %% [markdown]
# En este gráfico se puede apreciar la mayoría de las personas sufrieron violencia psicológica y doméstica

# %%
# Tipos de violencia por año
df_violencia = df[['Anio', 'tipo_de_violencia_fisica', 'tipo_de_violencia_psicologica', 'tipo_de_violencia_sexual', 'tipo_de_violencia_economica_y_patrimonial', 'tipo_de_violencia_simbolica', 'tipo_de_violencia_domestica']]

# Convertir "Si" a 1 y "No" a 0 en todas las columnas de tipo de violencia (antes de hacer dummies)
df_violencia_numerica = df_violencia.replace({'Si': 1,'SI': 1, 'No': 0})

df_agrupado = df_violencia_numerica.groupby('Anio').sum()

anios = df_agrupado.index
tipos_violencia = df_agrupado.columns

colores = ['lightsalmon', 'navajowhite', 'tomato', 'skyblue', 'mediumpurple', 'orchid']

# Gráfico
plt.figure(figsize=(10, 6))
bottom = np.zeros(len(anios))
for i, tipo_violencia in enumerate(tipos_violencia):
    plt.bar(anios, df_agrupado[tipo_violencia], bottom=bottom, color=colores[i], label=tipo_violencia)
    bottom += df_agrupado[tipo_violencia]

plt.legend(title='Tipo de violencia', bbox_to_anchor=(1, 1), loc='upper left')
plt.title('Tipos de violencia por año')
plt.xlabel('Año')
plt.ylabel('Cantidad de violencia')
plt.xticks(anios)
plt.show()

# %% [markdown]
# En el gráfico se puede visualizar la cantidad de violencia por año. Se observa que en el 2020 y 2021 se sufrió más violencia psicológica que en años posteriores. Además a medida del tiempo fue disminuyendo la cantidad de violencia recibida, según los datos tomados.

# %%
# histograma de edad para casos con violencia física
plt.figure(figsize=(10, 6))
sns.histplot(df_final[df_final['tipo_de_violencia_fisica'] == 'Si']['edad_persona_en_situacion_de_violencia'], kde=True)
plt.title('Distribución de edad para casos con violencia física')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# Las que sufrieron violencia fisica tienen entre 25 y 45 años

# %%
# gráfico de barras para violencia física por vínculo con la persona agresora
plt.figure(figsize=(10, 6))
sns.countplot(data=df_final, x='vinculo_con_la_persona_agresora', hue='tipo_de_violencia_fisica')
plt.title('Número de casos de violencia física por tipo de vínculo')
plt.xlabel('Vínculo con la persona agresora')
plt.ylabel('Número de casos')
plt.show()

# %%
# Ttabla de correlación para los tipos de violencia
df_corr = df_final[['tipo_de_violencia_fisica', 'tipo_de_violencia_psicologica', 'tipo_de_violencia_sexual', 'tipo_de_violencia_economica_y_patrimonial', 'tipo_de_violencia_simbolica', 'tipo_de_violencia_domestica']]
df_corr = df_corr.apply(lambda x: x == 'Si').astype(int)

# Graficar la matriz de correlación
plt.figure(figsize=(10, 8))
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm', center=0)
plt.title('Matriz de correlación entre tipos de violencia')
plt.show()

# %%
# Contar casos por tipo de violencia
counts = df[['tipo_de_violencia_fisica', 'tipo_de_violencia_psicologica', 'tipo_de_violencia_sexual', 'tipo_de_violencia_economica_y_patrimonial', 'tipo_de_violencia_simbolica', 'tipo_de_violencia_domestica']].apply(pd.Series.value_counts)

# Graficar
counts.plot(kind='bar', figsize=(12, 8), colormap='viridis')
plt.title('Comparación del número de casos entre tipos de violencia')
plt.xlabel('Tipo de violencia')
plt.ylabel('Número de casos')
plt.show()

# %% [markdown]
# # **Drop de variables**

# %% [markdown]
# Se eliminan las variables que no son de interés

# %%
df_final = df_final.drop(columns=['Anio'])
df_final = df_final.drop(columns=['Fecha'])
df_final = df_final.drop(columns=['modalidad_de_violencia_institucional'])
df_final = df_final.drop(columns=['modalidad_de_violencia_otras'])
df_final = df_final.drop(columns=['modalidad_de_violencia_mediatica'])
df_final = df_final.drop(columns=['modalidad_de_violencia_obstetrica'])
df_final = df_final.drop(columns=['modalidad_violencia_contra_libertad_reproductiva'])
df_final = df_final.drop(columns=['modalidad_de_violencia_laboral'])
df_final = df_final.drop(columns=['poblacion_provincia'])
df_final = df_final.drop(columns=['pais_nacimiento_persona_en_situacion_de_violencia'])

# %%
df_final
# Out:
#       prov_persona_en_situacion_violencia  \
# 0                            Buenos Aires
# 1                            Buenos Aires
# 2                              Entre Ríos
# 3                                 Mendoza
# 4                            Buenos Aires
# ...                                   ...
# 68425                        Buenos Aires
# 68426                        Buenos Aires
# 68428                        Buenos Aires
# 68429                        Buenos Aires
# 68430                        Buenos Aires
#
#        edad_persona_en_situacion_de_violencia tipo_de_violencia_fisica  \
# 0                                        19.0                       Si
# 1                                        46.0                       Si
# 2                                        28.0                       No
# 3                                        34.0                       No
# 4                                        38.0                       Si
# ...                                       ...                      ...
# 68425                                    36.0                       No
# 68426                                    30.0                       Si
# 68428                                    22.0                       Si
# 68429                                    44.0                       Si
# 68430                                    21.0                       Si
#
#       tipo_de_violencia_psicologica tipo_de_violencia_sexual  \
# 0                                Si                       Si
# 1                                Si                       No
# 2                                Si                       No
# 3                                Si                       No
# 4                                Si                       No
# ...                             ...                      ...
# 68425                            Si                       No
# 68426                            Si                       No
# 68428                            Si                       No
# 68429                            Si                       No
# 68430                            Si                       No
#
#       tipo_de_violencia_economica_y_patrimonial tipo_de_violencia_simbolica  \
# 0                                            No                          No
# 1                                            No                          Si
# 2                                            No                          Si
# 3                                            No                          No
# 4                                            Si                          No
# ...                                         ...                         ...
# 68425                                        No                          Si
# 68426                                        No                          Si
# 68428                                        No                          Si
# 68429                                        No                          Si
# 68430                                        No                          Si
#
#       tipo_de_violencia_domestica vinculo_con_la_persona_agresora  \
# 0                              No                            Otro
# 1                              Si                          Pareja
# 2                              Si                          Pareja
# 3                              Si                       Ex pareja
# 4                              Si                       Ex pareja
# ...                           ...                             ...
# 68425                          Si                          Pareja
# 68426                          Si                          Pareja
# 68428                          Si                       Ex pareja
# 68429                          Si                       Ex pareja
# 68430                          Si                          Pareja
#
#       genero_de_la_persona_agresora
# 0                             Varon
# 1                             Varon
# 2                             Varon
# 3                             Varon
# 4                             Varon
# ...                             ...
# 68425                         Varon
# 68426                         Varon
# 68428                         Varon
# 68429                         Varon
# 68430                         Varon
#
# [63145 rows x 10 columns]

# %%
df_final.drop(columns=['genero_de_la_persona_agresora'],inplace=True)

# %% [markdown]
# # **Transformación de variables categóricas**

# %%
# Codifica la categoria en valores numericos. Reemplaza la misma columna
label_encoder = LabelEncoder()

# %%
one_hot_encoder = OneHotEncoder()

# %% [markdown]
# ## **Provincia**

# %% [markdown]
# Label encoder reemplaza los valores por un número representativo en la misma columna

# %%
provincia_encoder = LabelEncoder()

# %%
# Para evitar la creación de una columna por cada categoría, utilicé Label Encoder, ya que había demasiadas categorías
df_final['prov_persona_en_situacion_violencia'] = provincia_encoder.fit_transform(df_final['prov_persona_en_situacion_violencia'])
# Out:
# <ipython-input-83-51ce3a4a27c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['prov_persona_en_situacion_violencia'] = provincia_encoder.fit_transform(df_final['prov_persona_en_situacion_violencia'])

# %%
df_final['prov_persona_en_situacion_violencia'].head(10)
# Out:
# 0     0
# 1     0
# 2     7
# 3    12
# 4     0
# 5     0
# 6    20
# 7    12
# 8    13
# 9    20
# Name: prov_persona_en_situacion_violencia, dtype: int64

# %%
provincia_encoder.classes_
# Out:
# array(['Buenos Aires', 'Catamarca', 'Chaco', 'Chubut',
#        'Ciudad Autónoma de Buenos Aires', 'Corrientes', 'Córdoba',
#        'Entre Ríos', 'Formosa', 'Jujuy', 'La Pampa', 'La Rioja',
#        'Mendoza', 'Misiones', 'Neuquén', 'Río Negro', 'Salta', 'San Juan',
#        'San Luis', 'Santa Cruz', 'Santa Fe', 'Santiago del Estero',
#        'Tierra del Fuego, Antártida e Islas del Atlántico Sur', 'Tucumán'],
#       dtype=object)

# %%
df_final
# Out:
#        prov_persona_en_situacion_violencia  \
# 0                                        0
# 1                                        0
# 2                                        7
# 3                                       12
# 4                                        0
# ...                                    ...
# 68425                                    0
# 68426                                    0
# 68428                                    0
# 68429                                    0
# 68430                                    0
#
#        edad_persona_en_situacion_de_violencia tipo_de_violencia_fisica  \
# 0                                        19.0                       Si
# 1                                        46.0                       Si
# 2                                        28.0                       No
# 3                                        34.0                       No
# 4                                        38.0                       Si
# ...                                       ...                      ...
# 68425                                    36.0                       No
# 68426                                    30.0                       Si
# 68428                                    22.0                       Si
# 68429                                    44.0                       Si
# 68430                                    21.0                       Si
#
#       tipo_de_violencia_psicologica tipo_de_violencia_sexual  \
# 0                                Si                       Si
# 1                                Si                       No
# 2                                Si                       No
# 3                                Si                       No
# 4                                Si                       No
# ...                             ...                      ...
# 68425                            Si                       No
# 68426                            Si                       No
# 68428                            Si                       No
# 68429                            Si                       No
# 68430                            Si                       No
#
#       tipo_de_violencia_economica_y_patrimonial tipo_de_violencia_simbolica  \
# 0                                            No                          No
# 1                                            No                          Si
# 2                                            No                          Si
# 3                                            No                          No
# 4                                            Si                          No
# ...                                         ...                         ...
# 68425                                        No                          Si
# 68426                                        No                          Si
# 68428                                        No                          Si
# 68429                                        No                          Si
# 68430                                        No                          Si
#
#       tipo_de_violencia_domestica vinculo_con_la_persona_agresora  \
# 0                              No                            Otro
# 1                              Si                          Pareja
# 2                              Si                          Pareja
# 3                              Si                       Ex pareja
# 4                              Si                       Ex pareja
# ...                           ...                             ...
# 68425                          Si                          Pareja
# 68426                          Si                          Pareja
# 68428                          Si                       Ex pareja
# 68429                          Si                       Ex pareja
# 68430                          Si                          Pareja
#
#       genero_de_la_persona_agresora
# 0                             Varon
# 1                             Varon
# 2                             Varon
# 3                             Varon
# 4                             Varon
# ...                             ...
# 68425                         Varon
# 68426                         Varon
# 68428                         Varon
# 68429                         Varon
# 68430                         Varon
#
# [63145 rows x 10 columns]

# %% [markdown]
# ## **Violencia física**

# %%
fisica_encoder = LabelEncoder()
df_final['tipo_de_violencia_fisica'] = fisica_encoder.fit_transform(df_final['tipo_de_violencia_fisica'])
# Out:
# <ipython-input-87-21ef8638dd20>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tipo_de_violencia_fisica'] = fisica_encoder.fit_transform(df_final['tipo_de_violencia_fisica'])

# %% [markdown]
# ## **Violencia psicológica**

# %%
psicologica_encoder = LabelEncoder()
df_final['tipo_de_violencia_psicologica'] = psicologica_encoder.fit_transform(df_final['tipo_de_violencia_fisica'])
# Out:
# <ipython-input-88-36bc6012cca8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tipo_de_violencia_psicologica'] = psicologica_encoder.fit_transform(df_final['tipo_de_violencia_fisica'])

# %%
df_final['tipo_de_violencia_psicologica'].unique()
# Out:
# array([1, 0])

# %%
df_final
# Out:
#        prov_persona_en_situacion_violencia  \
# 0                                        0
# 1                                        0
# 2                                        7
# 3                                       12
# 4                                        0
# ...                                    ...
# 68425                                    0
# 68426                                    0
# 68428                                    0
# 68429                                    0
# 68430                                    0
#
#        edad_persona_en_situacion_de_violencia  tipo_de_violencia_fisica  \
# 0                                        19.0                         1
# 1                                        46.0                         1
# 2                                        28.0                         0
# 3                                        34.0                         0
# 4                                        38.0                         1
# ...                                       ...                       ...
# 68425                                    36.0                         0
# 68426                                    30.0                         1
# 68428                                    22.0                         1
# 68429                                    44.0                         1
# 68430                                    21.0                         1
#
#        tipo_de_violencia_psicologica tipo_de_violencia_sexual  \
# 0                                  1                       Si
# 1                                  1                       No
# 2                                  0                       No
# 3                                  0                       No
# 4                                  1                       No
# ...                              ...                      ...
# 68425                              0                       No
# 68426                              1                       No
# 68428                              1                       No
# 68429                              1                       No
# 68430                              1                       No
#
#       tipo_de_violencia_economica_y_patrimonial tipo_de_violencia_simbolica  \
# 0                                            No                          No
# 1                                            No                          Si
# 2                                            No                          Si
# 3                                            No                          No
# 4                                            Si                          No
# ...                                         ...                         ...
# 68425                                        No                          Si
# 68426                                        No                          Si
# 68428                                        No                          Si
# 68429                                        No                          Si
# 68430                                        No                          Si
#
#       tipo_de_violencia_domestica vinculo_con_la_persona_agresora  \
# 0                              No                            Otro
# 1                              Si                          Pareja
# 2                              Si                          Pareja
# 3                              Si                       Ex pareja
# 4                              Si                       Ex pareja
# ...                           ...                             ...
# 68425                          Si                          Pareja
# 68426                          Si                          Pareja
# 68428                          Si                       Ex pareja
# 68429                          Si                       Ex pareja
# 68430                          Si                          Pareja
#
#       genero_de_la_persona_agresora
# 0                             Varon
# 1                             Varon
# 2                             Varon
# 3                             Varon
# 4                             Varon
# ...                             ...
# 68425                         Varon
# 68426                         Varon
# 68428                         Varon
# 68429                         Varon
# 68430                         Varon
#
# [63145 rows x 10 columns]

# %% [markdown]
# ## **Violencia sexual**

# %%
sexual_encoder = LabelEncoder()
df_final['tipo_de_violencia_sexual'] = sexual_encoder.fit_transform(df_final['tipo_de_violencia_sexual'])
# Out:
# <ipython-input-91-0f6b65a5d7c3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tipo_de_violencia_sexual'] = sexual_encoder.fit_transform(df_final['tipo_de_violencia_sexual'])

# %% [markdown]
# ## **Violencia económica y patrimonial**

# %%
economica_encoder = LabelEncoder()
df_final['tipo_de_violencia_economica_y_patrimonial'] = economica_encoder.fit_transform(df_final['tipo_de_violencia_economica_y_patrimonial'])
# Out:
# <ipython-input-92-651a2e48d18a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tipo_de_violencia_economica_y_patrimonial'] = economica_encoder.fit_transform(df_final['tipo_de_violencia_economica_y_patrimonial'])

# %% [markdown]
# ## **Violencia simbólica**

# %%
simbolica_encoder = LabelEncoder()
df_final['tipo_de_violencia_simbolica'] = simbolica_encoder.fit_transform(df_final['tipo_de_violencia_simbolica'])
# Out:
# <ipython-input-93-16b75149f157>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tipo_de_violencia_simbolica'] = simbolica_encoder.fit_transform(df_final['tipo_de_violencia_simbolica'])

# %% [markdown]
# ## **Violencia doméstica**

# %%
domestica_encoder = LabelEncoder()
df_final['tipo_de_violencia_domestica'] = domestica_encoder.fit_transform(df_final['tipo_de_violencia_domestica'])
# Out:
# <ipython-input-94-c09538e0e727>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tipo_de_violencia_domestica'] = domestica_encoder.fit_transform(df_final['tipo_de_violencia_domestica'])

# %% [markdown]
# ## **Vínculo con el agresor**

# %%
df_final['vinculo_con_la_persona_agresora'].value_counts()
# Out:
# vinculo_con_la_persona_agresora
# Ex pareja              32614
# Pareja                 23732
# Otro                    3997
# Otro familiar           1669
# Padre o tutor            854
# Superior jerarquico      272
# Madre o tutor              7
# Name: count, dtype: int64

# %%
vinculo_encoder = LabelEncoder()
df_final['vinculo_con_la_persona_agresora'] = vinculo_encoder.fit_transform(df_final['vinculo_con_la_persona_agresora'])
print(df_final['vinculo_con_la_persona_agresora'].head(10))
print("Clases:",vinculo_encoder.classes_)
# Out:
# 0    2
# 1    5
# 2    5
# 3    0
# 4    0
# 5    5
# 6    0
# 7    5
# 8    5
# 9    5
# Name: vinculo_con_la_persona_agresora, dtype: int64
# Clases: ['Ex pareja' 'Madre o tutor' 'Otro' 'Otro familiar' 'Padre o tutor'
#  'Pareja' 'Superior jerarquico']
# <ipython-input-96-5cb70a59d192>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['vinculo_con_la_persona_agresora'] = vinculo_encoder.fit_transform(df_final['vinculo_con_la_persona_agresora'])

# %%
df_final
# Out:
#        prov_persona_en_situacion_violencia  \
# 0                                        0
# 1                                        0
# 2                                        7
# 3                                       12
# 4                                        0
# ...                                    ...
# 68425                                    0
# 68426                                    0
# 68428                                    0
# 68429                                    0
# 68430                                    0
#
#        edad_persona_en_situacion_de_violencia  tipo_de_violencia_fisica  \
# 0                                        19.0                         1
# 1                                        46.0                         1
# 2                                        28.0                         0
# 3                                        34.0                         0
# 4                                        38.0                         1
# ...                                       ...                       ...
# 68425                                    36.0                         0
# 68426                                    30.0                         1
# 68428                                    22.0                         1
# 68429                                    44.0                         1
# 68430                                    21.0                         1
#
#        tipo_de_violencia_psicologica  tipo_de_violencia_sexual  \
# 0                                  1                         1
# 1                                  1                         0
# 2                                  0                         0
# 3                                  0                         0
# 4                                  1                         0
# ...                              ...                       ...
# 68425                              0                         0
# 68426                              1                         0
# 68428                              1                         0
# 68429                              1                         0
# 68430                              1                         0
#
#        tipo_de_violencia_economica_y_patrimonial  tipo_de_violencia_simbolica  \
# 0                                              0                            0
# 1                                              0                            1
# 2                                              0                            1
# 3                                              0                            0
# 4                                              1                            0
# ...                                          ...                          ...
# 68425                                          0                            1
# 68426                                          0                            1
# 68428                                          0                            1
# 68429                                          0                            1
# 68430                                          0                            1
#
#        tipo_de_violencia_domestica  vinculo_con_la_persona_agresora
# 0                                0                                2
# 1                                1                                5
# 2                                1                                5
# 3                                1                                0
# 4                                1                                0
# ...                            ...                              ...
# 68425                            1                                5
# 68426                            1                                5
# 68428                            1                                0
# 68429                            1                                0
# 68430                            1                                5
#
# [63145 rows x 9 columns]

# %% [markdown]
# # Detalle de transformación del dataset original

# %%
# Para conocer como cambió nuestro dataset
percent_difference = ((len(df_final) - len(df)) / len(df)) * 100
print(f"Porcentaje de diferencia entre df y df final: {percent_difference:.2f}%")
# Out:
# Porcentaje de diferencia entre df y df final: -29.48%

# %% [markdown]
# # **Guardar df final**

# %%
df_final.to_csv('df_final.csv',index=False)
